# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

print("Libraries Imported Successfully")
# Out:
# Libraries Imported Successfully

# %%
df = pd.read_csv('retail_sales_dataset.csv')

# %%
# !ls
# Out:
# retail_sales_dataset.csv  sample_data

# %%
df.head()
# Out:
#    Transaction ID        Date Customer ID  Gender  Age Product Category  \
# 0               1  2023-11-24     CUST001    Male   34           Beauty
# 1               2  2023-02-27     CUST002  Female   26         Clothing
# 2               3  2023-01-13     CUST003    Male   50      Electronics
# 3               4  2023-05-21     CUST004    Male   37         Clothing
# 4               5  2023-05-06     CUST005    Male   30           Beauty
#
#    Quantity  Price per Unit  Total Amount
# 0         3              50           150
# 1         2             500          1000
# 2         1              30            30
# 3         1             500           500
# 4         2              50           100

# %%
df.shape
# Out:
# (1000, 9)

# %%
df.columns
# Out:
# Index(['Transaction ID', 'Date', 'Customer ID', 'Gender', 'Age',
#        'Product Category', 'Quantity', 'Price per Unit', 'Total Amount'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Transaction ID    1000 non-null   int64
#  1   Date              1000 non-null   object
#  2   Customer ID       1000 non-null   object
#  3   Gender            1000 non-null   object
#  4   Age               1000 non-null   int64
#  5   Product Category  1000 non-null   object
#  6   Quantity          1000 non-null   int64
#  7   Price per Unit    1000 non-null   int64
#  8   Total Amount      1000 non-null   int64
# dtypes: int64(5), object(4)
# memory usage: 70.4+ KB

# %%
df.describe()
# Out:
#        Transaction ID         Age     Quantity  Price per Unit  Total Amount
# count     1000.000000  1000.00000  1000.000000     1000.000000   1000.000000
# mean       500.500000    41.39200     2.514000      179.890000    456.000000
# std        288.819436    13.68143     1.132734      189.681356    559.997632
# min          1.000000    18.00000     1.000000       25.000000     25.000000
# 25%        250.750000    29.00000     1.000000       30.000000     60.000000
# 50%        500.500000    42.00000     3.000000       50.000000    135.000000
# 75%        750.250000    53.00000     4.000000      300.000000    900.000000
# max       1000.000000    64.00000     4.000000      500.000000   2000.000000

# %%
df.isnull().sum()
# Out:
# Transaction ID      0
# Date                0
# Customer ID         0
# Gender              0
# Age                 0
# Product Category    0
# Quantity            0
# Price per Unit      0
# Total Amount        0
# dtype: int64

# %%
df.describe().sum()
# Out:
# Transaction ID    4291.819436
# Age               1261.073430
# Quantity          1016.646734
# Price per Unit    2274.571356
# Total Amount      5135.997632
# dtype: float64

# %%
df.columns
# Out:
# Index(['Transaction ID', 'Date', 'Customer ID', 'Gender', 'Age',
#        'Product Category', 'Quantity', 'Price per Unit', 'Total Amount'],
#       dtype='object')

# %%
print("rows and column:", df.shape)
# Out:
# rows and column: (1000, 9)

# %%
df.dtypes
# Out:
# Transaction ID       int64
# Date                object
# Customer ID         object
# Gender              object
# Age                  int64
# Product Category    object
# Quantity             int64
# Price per Unit       int64
# Total Amount         int64
# dtype: object

# %%
print(df.columns.tolist())
# Out:
# ['Transaction ID', 'Date', 'Customer ID', 'Gender', 'Age', 'Product Category', 'Quantity', 'Price per Unit', 'Total Amount']

# %%
df['Date'] = pd.to_datetime(df['Date'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Transaction ID    1000 non-null   int64
#  1   Date              1000 non-null   datetime64[ns]
#  2   Customer ID       1000 non-null   object
#  3   Gender            1000 non-null   object
#  4   Age               1000 non-null   int64
#  5   Product Category  1000 non-null   object
#  6   Quantity          1000 non-null   int64
#  7   Price per Unit    1000 non-null   int64
#  8   Total Amount      1000 non-null   int64
# dtypes: datetime64[ns](1), int64(5), object(3)
# memory usage: 70.4+ KB

# %%
print("Shape:", df.shape)
print("\nMissing Values:")
print(df.isnull().sum())

print("\nDuplicate Rows:")
print(df.duplicated().sum())
# Out:
# Shape: (1000, 9)
#
# Missing Values:
# Transaction ID      0
# Date                0
# Customer ID         0
# Gender              0
# Age                 0
# Product Category    0
# Quantity            0
# Price per Unit      0
# Total Amount        0
# dtype: int64
#
# Duplicate Rows:
# 0

# %%
print(df['Gender'].unique())
# Out:
# ['Male' 'Female']

# %%
print(df['Product Category'].unique())
# Out:
# ['Beauty' 'Clothing' 'Electronics']

# %%
df.describe()
# Out:
#        Transaction ID                           Date         Age     Quantity  \
# count     1000.000000                           1000  1000.00000  1000.000000
# mean       500.500000  2023-07-03 00:25:55.200000256    41.39200     2.514000
# min          1.000000            2023-01-01 00:00:00    18.00000     1.000000
# 25%        250.750000            2023-04-08 00:00:00    29.00000     1.000000
# 50%        500.500000            2023-06-29 12:00:00    42.00000     3.000000
# 75%        750.250000            2023-10-04 00:00:00    53.00000     4.000000
# max       1000.000000            2024-01-01 00:00:00    64.00000     4.000000
# std        288.819436                            NaN    13.68143     1.132734
#
#        Price per Unit  Total Amount
# count     1000.000000   1000.000000
# mean       179.890000    456.000000
# min         25.000000     25.000000
# 25%         30.000000     60.000000
# 50%         50.000000    135.000000
# 75%        300.000000    900.000000
# ...

# %%
df.describe()
# Out:
#        Transaction ID                           Date         Age     Quantity  \
# count     1000.000000                           1000  1000.00000  1000.000000
# mean       500.500000  2023-07-03 00:25:55.200000256    41.39200     2.514000
# min          1.000000            2023-01-01 00:00:00    18.00000     1.000000
# 25%        250.750000            2023-04-08 00:00:00    29.00000     1.000000
# 50%        500.500000            2023-06-29 12:00:00    42.00000     3.000000
# 75%        750.250000            2023-10-04 00:00:00    53.00000     4.000000
# max       1000.000000            2024-01-01 00:00:00    64.00000     4.000000
# std        288.819436                            NaN    13.68143     1.132734
#
#        Price per Unit  Total Amount
# count     1000.000000   1000.000000
# mean       179.890000    456.000000
# min         25.000000     25.000000
# 25%         30.000000     60.000000
# 50%         50.000000    135.000000
# 75%        300.000000    900.000000
# ...

# %%
df['Calculated Amount'] = df['Quantity'] * df['Price per Unit']

(df['Calculated Amount'] == df['Total Amount']).all()
# Out:
# np.True_

# %%
#check outliers
print("Minimum Age:", df['Age'].min())
print("Maximum Age:", df['Age'].max())
# Out:
# Minimum Age: 18
# Maximum Age: 64

# %%
print("Minimum Quantity:", df['Quantity'].min())
print("Maximum Quantity:", df['Quantity'].max())
# Out:
# Minimum Quantity: 1
# Maximum Quantity: 4

# %%
#business overwies
total_revenue = df['Total Amount'].sum()
total_transactions = df['Transaction ID'].nunique()
avg_transaction = df['Total Amount'].mean()

print("Total Revenue:", total_revenue)
print("Total Transactions:", total_transactions)
print("Average Transaction Value:", round(avg_transaction,2))
# Out:
# Total Revenue: 456000
# Total Transactions: 1000
# Average Transaction Value: 456.0

# %%
# insight -  The company generated a total revenue of X through Y transactions, with an average transaction value of Z.

# %%
#poduct category analysis
category_sales = df.groupby('Product Category')['Total Amount'].sum().sort_values(ascending=False)

print(category_sales)
# Out:
# Product Category
# Electronics    156905
# Clothing       155580
# Beauty         143515
# Name: Total Amount, dtype: int64

# %%
#product visualization
import matplotlib.pyplot as plt

plt.figure(figsize=(8,5))
category_sales.plot(kind='bar')

plt.title('Revenue by Product Category')
plt.xlabel('Product Category')
plt.ylabel('Revenue')

plt.show()

# %%
#gender analysis
gender_sales = df.groupby('Gender')['Total Amount'].sum()

print(gender_sales)
# Out:
# Gender
# Female    232840
# Male      223160
# Name: Total Amount, dtype: int64

# %%
#Gender visualization
gender_sales.plot(
    kind='pie',
    autopct='%1.1f%%',
    figsize=(6,6)
)

plt.ylabel('')
plt.title('Revenue Contribution by Gender')
plt.show()

# %%
#age analysis
plt.figure(figsize=(8,5))

plt.hist(df['Age'], bins=10)

plt.title('Age Distribution')
plt.xlabel('Age')
plt.ylabel('Frequency')

plt.show()

# %%
df['Month'] = df['Date'].dt.month_name()

# %%
#montly sales analysis
monthly_sales = df.groupby('Month')['Total Amount'].sum()

print(monthly_sales)
# Out:
# Month
# April        33870
# August       36960
# December     44690
# February     44060
# January      36980
# July         35465
# June         36715
# March        28990
# May          53150
# November     34920
# October      46580
# September    23620
# Name: Total Amount, dtype: int64

# %%
#sales Visualization
monthly_sales.plot(
    kind='line',
    marker='o',
    figsize=(10,5)
)

plt.title('Monthly Sales Trend')
plt.ylabel('Revenue')

plt.show()

# %%
import pandas as pd
df = pd.read_csv('retail_sales_dataset.csv')
df['Date'] = pd.to_datetime(df['Date'])
print("Mean:", df['Total Amount'].mean())
print("Median:", df['Total Amount'].median())
print("Mode:", df['Total Amount'].mode()[0])
print("Standard Deviation:", df['Total Amount'].std())
# Out:
# Mean: 456.0
# Median: 135.0
# Mode: 50
# Standard Deviation: 559.997631555123

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(8,6))
sns.heatmap(df.corr(numeric_only=True),
            annot=True,
            cmap='coolwarm')

plt.title('Correlation Heatmap')
plt.show()

# %%
customer_spending = df.groupby('Customer ID')['Total Amount'].sum()

customer_spending.sort_values(
    ascending=False
).head(10)
# Out:
# Customer ID
# CUST015    2000
# CUST412    2000
# CUST970    2000
# CUST547    2000
# CUST281    2000
# CUST416    2000
# CUST420    2000
# CUST927    2000
# CUST447    2000
# CUST342    2000
# Name: Total Amount, dtype: int64

# %%
top_customers = df.groupby('Customer ID')['Total Amount'] \
                  .sum() \
                  .sort_values(ascending=False) \
                  .head(10)

print(top_customers)
# Out:
# Customer ID
# CUST015    2000
# CUST412    2000
# CUST970    2000
# CUST547    2000
# CUST281    2000
# CUST416    2000
# CUST420    2000
# CUST927    2000
# CUST447    2000
# CUST342    2000
# Name: Total Amount, dtype: int64

# %%
import matplotlib.pyplot as plt

top_customers.plot(kind='bar', figsize=(10,5))

plt.title('Top 10 Customers by Revenue')
plt.ylabel('Revenue')
plt.xlabel('Customer ID')

plt.show()

# %% [markdown]
# # Recommendations
#
# 1. Focus marketing efforts on the highest revenue-generating product category to maximize sales growth.
#
# 2. Increase inventory levels during peak sales periods to prevent stock shortages and improve customer satisfaction.
#
# 3. Develop customer loyalty programs to retain high-value customers and encourage repeat purchases.
#
# 4. Create targeted promotional campaigns for the most active customer age groups.
#
# 5. Use customer demographic insights to personalize marketing strategies and improve engagement.

# %% [markdown]
# # Conclusion
#
# This Exploratory Data Analysis (EDA) project successfully analyzed retail sales data to identify sales trends, customer behavior, and product performance. The dataset was cleaned and validated before analysis. Various statistical techniques and visualizations, including bar charts, line plots, and heatmaps, were used to uncover meaningful insights.
#
# The analysis revealed important patterns in customer demographics, purchasing behavior, and product category performance. These insights can help the business make informed decisions related to marketing, inventory management, and customer retention strategies.
#
# Overall, the project demonstrates how data analytics can be used to transform raw retail data into actionable business insights.
